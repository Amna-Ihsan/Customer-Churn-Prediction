# %% [markdown]
# ### Import Packages

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import joblib

# %% [markdown]
# ### Load CSV data

# %%
df = pd.read_csv("Churn_Modelling.csv")

# %%
df.head(5)
# Out:
#    CustomerId   Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0    15634602  Hargrave          619    France  Female   42       2
# 1    15647311      Hill          608     Spain  Female   41       1
# 2    15619304      Onio          502    France  Female   42       8
# 3    15701354      Boni          699    France  Female   39       1
# 4    15737888  Mitchell          850     Spain  Female   43       2
#
#      Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       0.00              1          1               1        101348.88
# 1   83807.86              1          0               1        112542.58
# 2  159660.80              3          1               0        113931.57
# 3       0.00              2          0               0         93826.63
# 4  125510.82              1          1               1         79084.10
#
#    Exited
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0

# %%
df.isna().sum()
# Out:
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CustomerId       10000 non-null  int64
#  1   Surname          10000 non-null  str
#  2   CreditScore      10000 non-null  int64
#  3   Geography        10000 non-null  str
#  4   Gender           10000 non-null  str
#  5   Age              10000 non-null  int64
#  6   Tenure           10000 non-null  int64
#  7   Balance          10000 non-null  float64
#  8   NumOfProducts    10000 non-null  int64
#  9   HasCrCard        10000 non-null  int64
#  10  IsActiveMember   10000 non-null  int64
#  11  EstimatedSalary  10000 non-null  float64
#  12  Exited           10000 non-null  int64
# dtypes: float64(2), int64(8), str(3)
# memory usage: 1.2 MB

# %%
df.describe()
# Out:
#          CustomerId   CreditScore           Age        Tenure        Balance  \
# count  1.000000e+04  10000.000000  10000.000000  10000.000000   10000.000000
# mean   1.569094e+07    650.528800     38.921800      5.012800   76485.889288
# std    7.193619e+04     96.653299     10.487806      2.892174   62397.405202
# min    1.556570e+07    350.000000     18.000000      0.000000       0.000000
# 25%    1.562853e+07    584.000000     32.000000      3.000000       0.000000
# 50%    1.569074e+07    652.000000     37.000000      5.000000   97198.540000
# 75%    1.575323e+07    718.000000     44.000000      7.000000  127644.240000
# max    1.581569e+07    850.000000     92.000000     10.000000  250898.090000
#
#        NumOfProducts    HasCrCard  IsActiveMember  EstimatedSalary  \
# count   10000.000000  10000.00000    10000.000000     10000.000000
# mean        1.530200      0.70550        0.515100    100090.239881
# std         0.581654      0.45584        0.499797     57510.492818
# ...

# %%
df.shape
# Out:
# (10000, 13)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['CustomerId', 'Surname', 'CreditScore', 'Geography', 'Gender', 'Age',
#        'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard', 'IsActiveMember',
#        'EstimatedSalary', 'Exited'],
#       dtype='str')

# %% [markdown]
# ### Drop Customer Id and Surname

# %%
df.drop(columns=["CustomerId","Surname"],inplace=True)

# %%
df.head(3)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1

# %% [markdown]
# ### Convert categorical into numerical values

# %%
# from sklearn.preprocessing import LabelEncoder

# encoder = LabelEncoder()
# df['Gender'] = encoder.fit_transform(df['Gender'])
# df['Geography'] = encoder.fit_transform(df['Geography'])

df = pd.get_dummies(df, columns=["Geography", "Gender"], drop_first=True,dtype=int)

# %%
df.head(2)
# Out:
#    CreditScore  Age  Tenure   Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2      0.00              1          1
# 1          608   41       1  83807.86              1          0
#
#    IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0               1        101348.88       1                  0
# 1               1        112542.58       0                  0
#
#    Geography_Spain  Gender_Male
# 0                0            0
# 1                1            0

# %% [markdown]
# ### Create input feature x and target label y

# %%
x = df.drop(columns='Exited')
y = df['Exited']

# %%
joblib.dump(x.columns.tolist(), "model_columns.pkl")
# Out:
# ['model_columns.pkl']

# %%
x
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Geography_Germany  Geography_Spain  \
# 0                  1        101348.88                  0                0
# ...

# %%
y
# Out:
# 0       1
# 1       0
# 2       1
# 3       0
# 4       0
#        ..
# 9995    0
# 9996    0
# 9997    1
# 9998    1
# 9999    0
# Name: Exited, Length: 10000, dtype: int64

# %% [markdown]
# ### Split data intro training and testing sets

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42,stratify=y)

# %%
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((8000, 11), (2000, 11), (8000,), (2000,))

# %% [markdown]
# ### Bring all values to one scale

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_train_scale = scaler.fit_transform(x_train)
x_test_scale = scaler.transform(x_test)

# %% [markdown]
# ### Train model

# %%
from sklearn.ensemble import RandomForestClassifier
rf_model = RandomForestClassifier(random_state=42, n_estimators=100)
rf_model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
rf_pred = rf_model.predict(x_test)
# rf_prob = rf_model.predict_proba(x_test)[:, 1]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

print("Random Forest Accuracy:", accuracy_score(y_test, rf_pred))
print(confusion_matrix(y_test, rf_pred))
print(classification_report(y_test, rf_pred))
# Out:
# Random Forest Accuracy: 0.8645
# [[1541   52]
#  [ 219  188]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      1593
#            1       0.78      0.46      0.58       407
#
#     accuracy                           0.86      2000
#    macro avg       0.83      0.71      0.75      2000
# weighted avg       0.86      0.86      0.85      2000

# %%
# y_prob = rf_model.predict_proba(x_test_scale)[:, 1]

# plot_df = x_test.copy()
# plot_df["Actual"] = y_test.values
# plot_df["Predicted_Probability"] = rf_prob

# age_prob = plot_df.groupby("Age")["Predicted_Probability"].mean().reset_index()

# plt.figure(figsize=(8, 5))
# plt.plot(age_prob["Age"], age_prob["Predicted_Probability"], marker="o")

# plt.xlabel("Age")
# plt.ylabel("Average Predicted Probability of Exited")
# plt.title("Average Predicted Churn Probability by Age")
# plt.show()

# %%
# age_grid = np.linspace(x_test["Age"].min(), x_test["Age"].max(), 200)

# # Create one average customer
# base_customer = x_train.median(numeric_only=True)

# # Repeat this customer for all ages
# age_curve = pd.DataFrame([base_customer] * len(age_grid))

# # Change only Age
# age_curve["Age"] = age_grid

# # Keep same column order as training data
# age_curve = age_curve[x_train.columns]

# # Scale using the same scaler
# age_curve_scaled = scaler.transform(age_curve)

# # Predict probability
# age_curve_prob = rf_prob.predict_proba(age_curve_scaled)[:, 1]

# plt.figure(figsize=(8, 5))
# plt.plot(age_grid, age_curve_prob)

# plt.xlabel("Age")
# plt.ylabel("Predicted Probability of Exited")
# plt.title("Smooth Logistic Regression Curve by Age")
# plt.show()

# %%
from sklearn.linear_model import LogisticRegression
lg_model = LogisticRegression(max_iter=1000)
lg_model.fit(x_train_scale,y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
lg_pred = lg_model.predict(x_test_scale)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix,classification_report

print("Logistic Regression Accuracy:", accuracy_score(y_test, lg_pred))
print(confusion_matrix(y_test, lg_pred))
print(classification_report(y_test, lg_pred))
# Out:
# Logistic Regression Accuracy: 0.808
# [[1540   53]
#  [ 331   76]]
#               precision    recall  f1-score   support
#
#            0       0.82      0.97      0.89      1593
#            1       0.59      0.19      0.28       407
#
#     accuracy                           0.81      2000
#    macro avg       0.71      0.58      0.59      2000
# weighted avg       0.78      0.81      0.77      2000

# %%
joblib.dump(rf_model, "rf_model.pkl")

joblib.dump(scaler, "scaler.pkl")
print("model saved successfully")
# Out:
# model saved successfully
